# %%
import os
from osgeo import gdal
import numpy as np
from PIL import Image
import xml.etree.ElementTree as ET

# %%
# Specify input and output folders
input_folder = "/Users/gilisaacgabriel/Library/CloudStorage/OneDrive-TheOhioStateUniversity/AppEARS DEM/NC"
output_folder = "/Users/gilisaacgabriel/Library/CloudStorage/OneDrive-TheOhioStateUniversity/AppEARS DEM/NC/PNG"

# %%
def get_statistics(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    statistics = {}

    metadata = root.find('.//Metadata')
    if metadata is not None:
        for mdi in metadata.findall('.//MDI'):
            statistics[mdi.attrib['key']] = float(mdi.text)

    return statistics

def normalize_array(array):
    """
    Normalize array values to range [0, 1]
    """
    min_val = np.min(array)
    max_val = np.max(array)
    normalized_array = (array - min_val) / (max_val - min_val)
    return normalized_array

def apply_color_mapping(array, min_val, max_val):
    """
    Apply color mapping based on minimum and maximum values
    """
    normalized_array = normalize_array(array)
    scaled_array = 255 * (normalized_array - min_val) / (max_val - min_val)
    return scaled_array.astype(np.uint8)

# %%
def stretch_contrast(image, min_val, max_val):
    """
    Stretch contrast of the image to the specified min and max values.
    """
    # Clip values below min_val and above max_val
    stretched_image = np.clip(image, min_val, max_val)
    
    # Normalize to range [0, 1]
    stretched_image = (stretched_image - min_val) / (max_val - min_val)
    
    # Scale to range [0, 255]
    stretched_image = (stretched_image * 255).astype(np.uint8)
    
    return stretched_image

def geotiff_to_png(input_folder, output_folder):
    # Make sure output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get list of GeoTIFF files in the input folder
    tiff_files = [f for f in os.listdir(input_folder) if f.endswith('.tif') or f.endswith('.tiff')]

    for tiff_file in tiff_files:
        # Open GeoTIFF file
        tiff_path = os.path.join(input_folder, tiff_file)
        dataset = gdal.Open(tiff_path)
        if dataset is None:
            print(f"Could not open {tiff_file}")
            continue

        # Read raster data
        band = dataset.GetRasterBand(1)
        raster = band.ReadAsArray()

        # Get corresponding XML file
        xml_file = tiff_file + '.aux.xml'  # Adding .aux.xml suffix
        xml_path = os.path.join(input_folder, xml_file)

        # Check if XML file exists
        if not os.path.exists(xml_path):
            print(f"XML file not found for {tiff_file}")
            continue

        # Get statistics from XML file
        statistics = get_statistics(xml_path)

        # Extract min and max height from statistics
        min_height = statistics.get('STATISTICS_MINIMUM', 0)
        max_height = statistics.get('STATISTICS_MAXIMUM', 65535)  # Default to 65535 if maximum not found

        # Apply histogram stretching
        stretched_image = stretch_contrast(raster, min_height, max_height)

        # Create PNG image
        image = Image.fromarray(stretched_image)

        # Save PNG file with 16-bit depth
        png_file = os.path.splitext(tiff_file)[0] + '.png'
        png_path = os.path.join(output_folder, png_file)
        image.save(png_path, format='PNG', bitdepth=16)

        print(f"Converted {tiff_file} to {png_file}")

    print("Conversion complete.")

# %%
# Convert GeoTIFF files to PNG
geotiff_to_png(input_folder, output_folder)
# Out:
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0066.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0066.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0072.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0072.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0073.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0073.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0067.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0067.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0071.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0071.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0065.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0065.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0059.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0059.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0058.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0058.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0064.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0064.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0070.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0070.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0048.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0048.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0074.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0074.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0060.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0060.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0061.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0061.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0075.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0075.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0049.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0049.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0063.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0063.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0077.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0077.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0076.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0076.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0062.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0062.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0039.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0039.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0038.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0038.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0027 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0027 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0037 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0037 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0036 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0036 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0026 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0026 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0028.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0028.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0029.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0029.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0015 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0030.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0030.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0031.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0031.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0026 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0026 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0033.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0033.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0027.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0027.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0026.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0026.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0041 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0041 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0032.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0032.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0036.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0036.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0027 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0027 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0040 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0040 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0023.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0037.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0037.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0032 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0032 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0004 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0035.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0035.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0034.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0034.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0022 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0047.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0047.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0053.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0053.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0020 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0030 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0030 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0052.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0052.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0046.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0046.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0042 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0042 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0050.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0050.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0006 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0016 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0044.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0044.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0078.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0078.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0045.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0045.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0051.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0051.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0014 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0003 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0013 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0010 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0069.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0069.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0055.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0055.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0041.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0041.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0017 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0007 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0001 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0011 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0040.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0040.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0054.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0054.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0068.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0068.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0028 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0028 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (6).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0005 (6).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0012 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0002 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0009 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (5).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0019 (5).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (2).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0024 (2).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0042.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0042.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0056.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0056.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0021 (1).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0057.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0057.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0043.tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0043.png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025 (3).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0025 (3).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0018 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (4).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0008 (4).png
# Converted SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0043 (1).tif to SRTMGL1_NC.003_SRTMGL1_DEM_doy2000042_aid0043 (1).png
# Conversion complete.
